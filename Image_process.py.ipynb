# %%
import pytesseract
from PIL import Image
from glob import glob
import pylab as plt

# Define the coordinates of the subimage
x1 = 0
y1 = 0
x2 = 100
y2 = 100

images = glob('../../Data/Waste recognition/Pictures/*.JPG')
for image in images:
    # 開啟圖片
    image = Image.open(image)
    
    # Crop the subimage
    subimg = image.crop((x1, y1, x2, y2))
    plt.imshow(subimg)

#     # 將圖片轉成灰階
#     gray_image = image.convert('L')

#     # 進行文字識別
#     text = pytesseract.image_to_string(gray_image)

#     # 顯示識別結果
#     print(text)
#     import pytesseract
#     from PIL import Image

#     # 開啟圖片
#     image = Image.open('your_image_path.jpg')

#     # 將圖片轉成灰階
#     gray_image = image.convert('L')

#     # 進行文字識別
#     text = pytesseract.image_to_string(gray_image)

#     # 顯示識別結果
#     print(text)
